# %% [markdown]
# # Install python packages to Gdrive for reuse in Colab

# %%
import os, sys 
#to be able to interact with Google Drive's operating system
from google.colab import drive 
#drive is a module that allows us use Python to interact with google drive
drive.mount('/content/gdrive') 
#mounting google drive allows us to work with its contents
nb_path = '/content/notebooks'
os.symlink('/content/gdrive/My Drive/Colab Notebooks', nb_path)
sys.path.insert(0, nb_path)  # or append(nb_path)
#The last three lines are what changes the path of the file.
# Out:
# Mounted at /content/gdrive

# %%
# !pip install --upgrade --target=$nb_path pyicu
# !pip install --upgrade --target=$nb_path unicodedataplus
# !pip install --upgrade --target=$nb_path pymarc
# !pip install --upgrade --target=$nb_path regex
# !pip install --upgrade --target=$nb_path -U git+https://github.com/enabling-languages/el_internationalisation.git#egg=el_internationalisation
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 257.9/257.9 kB 5.0 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# ...
#   Created wheel for pyicu: filename=PyICU-2.11-cp310-cp310-linux_x86_64.whl size=1855620 sha256=a0ad899f8ae216c6b8aa48f983eb63bdfe90461f3112036b52a679dad099fed3
#   Stored in directory: /root/.cache/pip/wheels/67/c3/00/2176cc05d3ea22935a9c78f1034b1a3e3697ef11ffb5cbe2f5
# Successfully built pyicu
# ...
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 564.8/564.8 kB 9.8 MB/s eta 0:00:00
# ...
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 157.0/157.0 kB 4.0 MB/s eta 0:00:00
# ...

# %%
import el_internationalisation

# %%
# !pip install --target=$nb_path --no-deps -U git+https://github.com/enabling-languages/el_utilities.git#egg=el_utilities
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#   Cloning https://github.com/enabling-languages/el_utilities.git to /tmp/pip-install-qnauagr0/el-utilities_1505d404924d4349b302d29fdc5b01ab
#   Running command git clone --filter=blob:none --quiet https://github.com/enabling-languages/el_utilities.git /tmp/pip-install-qnauagr0/el-utilities_1505d404924d4349b302d29fdc5b01ab
#   Resolved https://github.com/enabling-languages/el_utilities.git to commit 6b3cb7dd86c2ecbba06379438888b8988fd84c85
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for el_utilities: filename=el_utilities-0.1.1-py3-none-any.whl size=21605 sha256=736d47fe7eb3607ca27649b48cdc130051761969833d5d82fbe71ba6a6f7e782
#   Stored in directory: /tmp/pip-ephem-wheel-cache-riyj543g/wheels/a2/ae/5a/f73d55289c4d77b8203fcde1c2c510ce7989847e0133027e51
# Successfully built el_utilities
# ...

# %%
# Test packages
import el_utilities
import el_internationalisation

# %%
import regex, collections, pathlib, sys, icu, copy, functools, prettytable, unicodedataplus
import xml.etree.ElementTree
import pymarc
